# %%
from PIL import Image

# %%
im = Image.open(r"images/1h_0.jpg")
im.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240 at 0x7F3C08378940>

# %%
width, height = im.size

left = width / 5
top = height / 6
bottom = height / 5 * 3
right = width / 8 * 7

im_crop = im.crop((left, top, right, bottom))
im1.show()
print(im1.size)
# Out:
# <PIL.Image.Image image mode=RGB size=216x104 at 0x7F3BF84220A0>
# (216, 104)

# %%
for file in os.listdir("images/"):
    im = Image.open(r"images/" + file)
    width, height = im.size

    left = width / 5
    top = height / 6
    bottom = height / 5 * 3
    right = width / 8 * 7

    im_crop = im.crop((left, top, right, bottom))
